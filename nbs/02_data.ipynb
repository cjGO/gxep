# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # data
#
# > Fill in a module description here

# %%
#| default_exp data

# %%
#| hide
from nbdev.showdoc import *

# %%
#| export
import numpy as np
import pandas as pd
from gxep.config import *

def load_data():
    #load csv from marker_data_path
    marker = pd.read_csv(marker_data_path)
    #load csv from training_data_path
    train = pd.read_csv(train_data_path)
    test = pd.read_csv(test_data_path)
    return marker, train, test

marker, train, test = load_data()
# Out:
# /mnt/c/Users/cltng/gdrive/gxep/data/GenomicMarkers.csv

# %%
train
# Out:
#        genotype.id  replicate  tillering  leaf.size    maturity  \
# 0            16511          1   0.331522  50.162086  183.285109
# 1            16512          1   0.331522  46.999032  178.502612
# 2            16513          1   0.202364  47.820026  192.200527
# 3            16514          1  -0.124731  51.092366  182.065940
# 4            16515          1   0.004426  50.113996  171.447907
# ...            ...        ...        ...        ...         ...
# 17995        18006          2   0.359352  47.024942  152.145103
# 17996        18007          2  -0.152562  50.899653  180.855535
# 17997        18008          2  -0.152562  46.615183  180.516520
# 17998        18009          2   0.331522  43.851216  158.947579
# 17999        18010          2   0.331522  44.760751  160.412749
#
#        plant.density  environment       yield
# 0                 25    Dalby_Dry  195.845326
# 1                 25    Dalby_Dry  214.700708
# 2                 25    Dalby_Dry  197.179665
# ...

# %%
test
# Out:
#       genotype.id  replicate  tillering  leaf.size    maturity  plant.density  \
# 0           16511          1   0.331522  50.162086  183.285109             75
# 1           16512          1   0.331522  46.999032  178.502612             75
# 2           16513          1   0.202364  47.820026  192.200527             75
# 3           16514          1  -0.124731  51.092366  182.065940             75
# 4           16515          1   0.004426  50.113996  171.447907             75
# ...           ...        ...        ...        ...         ...            ...
# 1495        18006          1   0.359352  47.024942  152.145103             75
# 1496        18007          1  -0.152562  50.899653  180.855535             75
# 1497        18008          1  -0.152562  46.615183  180.516520             75
# 1498        18009          1   0.331522  43.851216  158.947579             75
# 1499        18010          1   0.331522  44.760751  160.412749             75
#
#       environment       yield
# ...

# %%
#| hide
import nbdev; nbdev.nbdev_export()
